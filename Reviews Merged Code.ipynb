# %%
import pandas as pd

# %%
df1= pd.read_csv('ReviewsTor.csv')

# %%
df2=pd.read_csv("ReviewsMon.csv")

# %%
df3=pd.read_csv("ReviewsVan.csv")

# %%
df1.shape
# Out:
# (610649, 6)

# %%
df2.shape
# Out:
# (445762, 6)

# %%
df3.shape
# Out:
# (214226, 6)

# %%
import missingno as msno

# %%
msno.matrix(df1)

# %%
df1=df1.dropna(how='any')

# %%
df2=df2.dropna(how='any')

# %%
df3=df3.dropna(how='any')

# %%
msno.matrix(df1)

# %%
msno.matrix(df2)

# %%
msno.matrix(df3)

# %%
df= pd.concat([df1,df2,df3],ignore_index=True)

# %%
df.shape
# Out:
# (1269870, 6)

# %%
msno.matrix(df)

# %%
df.to_csv('MergedReviews.csv')
